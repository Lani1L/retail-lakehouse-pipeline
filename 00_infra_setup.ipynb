# %%
# %sql
-- Create Catalog
CREATE CATALOG IF NOT EXISTS retail_lakehouse_prod;

-- Create Medallion Schemas
CREATE SCHEMA IF NOT EXISTS retail_lakehouse_prod.bronze;
CREATE SCHEMA IF NOT EXISTS retail_lakehouse_prod.silver;
CREATE SCHEMA IF NOT EXISTS retail_lakehouse_prod.gold;

-- Create config and checkpoint for the path and indepotency
CREATE SCHEMA IF NOT EXISTS retail_lakehouse_prod.config;
CREATE VOLUME IF NOT EXISTS retail_lakehouse_prod.config.checkpoints;
